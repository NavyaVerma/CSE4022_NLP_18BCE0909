# %%
import nltk
# BASIC TEXT PROCESSING PIPELINE
text1 = '''A typical essay contains many different kinds of information, often located in specialized parts or sections. 
Even short essays perform several different operations: introducing the argument, analyzing data, raising counterarguments, concluding. 
Introductions and conclusions have fixed places, but other parts don't. 
Counterargument, for example, may appear within a paragraph, as a free-standing section, as part of the beginning, or before the ending. 
Background material (historical context or biographical information, a summary of relevant theory or criticism, the definition of a key term) often appears at the beginning of the essay, between the introduction and the first analytical section, but might also appear near the beginning of the specific section to which it's relevant.'''
for text in text1:
    sentences = nltk.sent_tokenize(text1)
    for sentence in sentences:
        words=nltk.word_tokenize(sentence)
        tagged=nltk.pos_tag(words)
        print(tagged)
# Out:
# [('A', 'DT'), ('typical', 'JJ'), ('essay', 'NN'), ('contains', 'VBZ'), ('many', 'JJ'), ('different', 'JJ'), ('kinds', 'NNS'), ('of', 'IN'), ('information', 'NN'), (',', ','), ('often', 'RB'), ('located', 'VBN'), ('in', 'IN'), ('specialized', 'JJ'), ('parts', 'NNS'), ('or', 'CC'), ('sections', 'NNS'), ('.', '.')]
# [('Even', 'RB'), ('short', 'JJ'), ('essays', 'NNS'), ('perform', 'VB'), ('several', 'JJ'), ('different', 'JJ'), ('operations', 'NNS'), (':', ':'), ('introducing', 'VBG'), ('the', 'DT'), ('argument', 'NN'), (',', ','), ('analyzing', 'VBG'), ('data', 'NNS'), (',', ','), ('raising', 'VBG'), ('counterarguments', 'NNS'), (',', ','), ('concluding', 'VBG'), ('.', '.')]
# [('Introductions', 'NNS'), ('and', 'CC'), ('conclusions', 'NNS'), ('have', 'VBP'), ('fixed', 'VBN'), ('places', 'NNS'), (',', ','), ('but', 'CC'), ('other', 'JJ'), ('parts', 'NNS'), ('do', 'VBP'), ("n't", 'RB'), ('.', '.')]
# ...

# %%
# TWEET TOKENIZER
from nltk.tokenize import TweetTokenizer
text='The party was so fun :D #superfun'
twtkn=TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['The', 'party', 'was', 'so', 'fun', ':D', '#superfun']

# %%
# SCRAPING DATA FROM WEB
from urllib import request
url="http://www.gutenberg.org/files/2554/2554-0.txt"
response=request.urlopen(url)
raw=response.read().decode('utf8')
type(raw)
# Out:
# str

# %%
len(raw)
# Out:
# 1176967

# %%
raw[:75]
# Out:
# '\ufeffThe Project Gutenberg EBook of Crime and Punishment, by Fyodor Dostoevsky\r'

# %%
from nltk.tokenize import word_tokenize
tokens=word_tokenize(raw)
type(tokens)
# Out:
# list

# %%
# HTML => ASCII => TEXT => VOCAB

# %%
# HANDLING TWEETS DATA
import nltk
f = open('tweets1.txt', 'r')
text=f.read()
text1=text.split()
text2=nltk.Text(text1)
text2.concordance("good")
# Out:
# Displaying 17 of 17 matches:
# n The Signal premiere. Lotsa buyers. Good luck gang listening to the pocast ne
# so going to enjoy this shower. Feels good to have worked on a trail three time
# ose not my friend. it was not a very good day so I have a lot to do tomorrow..
# Oh why cheesecake why? You looked so good evil cake. Now metamucil. Reading: "
# utiful day so Im thinking to spend a good part of it outdoors.first stop at St
# g and ignoring my reaction to a very good friend getting fired. it's like a bi
# d HDH - url wrist sprain= damn pain. good thing it's not on my left hand. Bein
#  I bet I can throw farther than her. Good luck with that dude. Sure it will al
#  Choppers. first day of eid .. feels good Looking to buy a game called Shut th
# g. back from the ASLA 6 Congress. :) Good job ASLA CORE! I'm gonna need to ste
# tching the CNBC video of David Lear. Good job Sean! and now... off to Belize!
# ...
